# %% [markdown]
# <a href="https://colab.research.google.com/github/NamanBansal9/UCS420/blob/main/Lab/Assiqnment_solution_of_Learn_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1 Hello World**

# %% [markdown]
# **Assingment 1.1**: WAP to print your name three times
#
# **Solution**

# %%
i = 0
while i < 3 :
  print('Naman Bansal')
  i = i + 1
# Out:
# Naman Bansal
# Naman Bansal
# Naman Bansal

# %% [markdown]
# # **2 Add numbers and Concatinate strings**

# %% [markdown]
# **Assingment 2.1**: WAP to add three numbers and print the result.
#
# **Solution**

# %%
a = 97
b = 98
c = 99
print(a,'+',b,'+',c,'-->>',a+b+c)
# Out:
# 97 + 98 + 99 -->> 294

# %% [markdown]
# **Assingment 2.2**: WAP to concatinate three strings and print the result.
#
# **Solution**

# %%
a = "I"
b = "am"
c = "Naman"
print("Hello!",a,b,c)
# Out:
# Hello! I am Naman

# %% [markdown]
# # **4 Loop**

# %% [markdown]
# **Assingment 4.1:** WAP to print the table of 7, 9.
#
# **Solution**

# %%
for i in range(1,11):
  print('7 *',i,'=',7*i)
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70

# %%
i = 1
while i < 11:
  print('9 *',i,'=',9*i)
  i = i + 1
# Out:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 9 * 10 = 90

# %% [markdown]
# **Assingment 4.2:** WAP to print the table of n and n is given by user.
#
# **Solution**

# %%
k = input('Enter the number darling : ')
n = int(k)
for i in range(1,11):
  print(n,'*',i,'-->>',n*i)
#try k in place of n as k is working as char or string there
# Out:
# Enter the number darling : 9
# 9 * 1 -->> 9
# 9 * 2 -->> 18
# 9 * 3 -->> 27
# 9 * 4 -->> 36
# 9 * 5 -->> 45
# 9 * 6 -->> 54
# 9 * 7 -->> 63
# 9 * 8 -->> 72
# 9 * 9 -->> 81
# 9 * 10 -->> 90

# %% [markdown]
# **Assingment 4.3:** WAP to add all the numbers from 1 to n and n is given by user.
#
# **Solution**

# %%
n = int(input('enter the no. : '))
n = n + 1
print('sum from 1 to', n-1, '-->>',sum(range(1,n)))
# Out:
# enter the no. : 2
# sum from 1 to 2 -->> 3

# %% [markdown]
# # **5 If-Else - Conditional Checking**

# %% [markdown]
# **Assingment 5.1:** WAP to find max amoung three numbers and input from user. [Try max() function]
#
# **Solution**

# %%
a = int(input('enter the first no. : '))
b = int(input('enter the second no. : '))
c = int(input('enter the third no. : '))
print('max no. among your fav. ones [',a,',',b,',',c,'] :',max(a,b,c))
# Out:
# enter the first no. : 9
# enter the second no. : 8
# enter the third no. : 7
# max no. among your fav. ones [ 9 , 8 , 7 ] : 9

# %% [markdown]
# **Assingment 5.2:** WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user.
#
# **Solution**

# %%
n = int(input('enter the no. to optimize with fun : '))
k = n//(9*7)
sum = (9*7)*k*(k+1)/2
print('sum of all no.\'s divisible by 63 upto',n,'is -->>',int(sum))
# Out:
# enter the no. to optimize with fun : 63
# sum of all no.'s divisible by 63 upto 63 is -->> 63

# %% [markdown]
# **Assingment 5.3:** WAP to add all prime numbers from 1 to n and n is given by the user.
#
# **Solution**

# %%
import math
n = int(input('enter the no. :'))
s = 0
for i in range(1,n+1):
  g = 1
  for j in range(2,int(math.sqrt(i))+1):
    if i % j == 0 :
      g = 0
      break
  if g == 1:
    s = s + i

print('sum of all prime numbers from 1 to',n,'is -->>',s)
# Out:
# enter the no. :5
# sum of all prime numbers from 1 to 5 is -->> 11

# %% [markdown]
# # **6 Functions**

# %% [markdown]
# **Assingment 6.1:** WAP using function that add all odd numbers from 1 to n, n is given by the user.
#
# **Solution**

# %%
n = int(input('enter the no.: '))
s = 0
for i in range(1,n+1):
  if i % 2 != 0:
    s = s + i
print('sum of all odd no. up to ',n,'is :',s)
# Out:
# enter the no.: 5
# sum of all odd no. up to  5 is : 9

# %% [markdown]
# **Assingment 6.2:** WAP using function that add all prime numbers from 1 to n, n given by the user.

# %%
import math
n = int(input('enter the no. :'))
s = 0
for i in range(1,n+1):
  g = 1
  for j in range(2,int(math.sqrt(i))+1):
    if i % j == 0 :
      g = 0
      break
  if g == 1:
    s = s + i

print('sum of all prime numbers from 1 to',n,'is -->>',s)
# Out:
# enter the no. :5
# sum of all prime numbers from 1 to 5 is -->> 11
